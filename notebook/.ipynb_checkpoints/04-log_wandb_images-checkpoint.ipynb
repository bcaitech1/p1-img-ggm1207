# %% [markdown]
# # Matplotlib and Wandb

# %%
import os
import sys

import torch
import torch.nn as nn
import torch.nn.functional as F

os.chdir('/opt/ml/P-Stage/1-STAGE/')

from config import get_args
from prepare import get_dataloader

# %%
weight_path = "/opt/ml/weights"

age_path = os.path.join(weight_path, "age.pt")
mask_path = os.path.join(weight_path, "mask.pt")
gender_path = os.path.join(weight_path, "gender.pt")

age_model = torch.load(age_path)
mask_model = torch.load(mask_path)
gender_model = torch.load(gender_path)

# %%
args = get_args()
args.train_key = 'gender'
args.test = True

# %%
train_dataloader, test_dataloader = get_dataloader(args)

# %%
images, labels = next(iter(train_dataloader))
images, labels = images.cuda(), labels.cuda()

# %%
outputs = age_model(images)

# %%
# images, outputs, labels
# 하나의 모델, Train 할 때
# 여러개의 모델, Predict 할 때

# %%
import matplotlib.pyplot as plt

# %%
images_len = len(images)

# %%
col_num = int(len(images) ** 0.5)
col_num
# Out:
# 8

# %%
outputs = F.softmax(outputs, dim=1)
outputs
# Out:
# tensor([[4.4692e-01, 4.7026e-01, 8.2817e-02],
#         [1.3382e-01, 5.1264e-01, 3.5355e-01],
#         [9.1422e-01, 8.5364e-02, 4.1986e-04],
#         [8.4735e-01, 1.5256e-01, 9.4914e-05],
#         [2.0026e-02, 6.4177e-01, 3.3821e-01],
#         [1.3382e-01, 5.1264e-01, 3.5355e-01],
#         [1.3820e-02, 3.4012e-01, 6.4606e-01],
#         [3.0072e-01, 6.4373e-01, 5.5558e-02],
#         [8.5523e-01, 1.4437e-01, 4.0546e-04],
#         [2.6275e-01, 7.3549e-01, 1.7553e-03],
#         [2.1403e-01, 7.7937e-01, 6.5982e-03],
#         [4.0769e-01, 5.9165e-01, 6.6224e-04],
#         [9.2674e-01, 7.2936e-02, 3.2483e-04],
#         [8.5598e-01, 1.4331e-01, 7.0765e-04],
#         [8.3877e-01, 1.6101e-01, 2.1761e-04],
#         [2.9084e-01, 7.0609e-01, 3.0702e-03],
#         [2.5768e-01, 7.3632e-01, 5.9922e-03],
#         [5.0218e-01, 4.9319e-01, 4.6280e-03],
#         [8.8354e-01, 1.1566e-01, 8.0039e-04],
#         [9.2579e-01, 7.3822e-02, 3.8491e-04],
#         [7.4144e-01, 2.5622e-01, 2.3467e-03],
#         [2.5630e-01, 7.3698e-01, 6.7230e-03],
#         [9.3628e-01, 6.3513e-02, 2.0505e-04],
#         [8.9968e-01, 1.0003e-01, 2.9571e-04],
#         [3.6513e-02, 8.7396e-01, 8.9532e-02],
#         [1.2132e-02, 4.3216e-01, 5.5571e-01],
#         [8.9442e-01, 1.0513e-01, 4.5150e-04],
#         [7.5934e-03, 5.8902e-01, 4.0338e-01],
#         [3.4935e-01, 6.4752e-01, 3.1277e-03],
#         [8.7515e-01, 1.2432e-01, 5.2815e-04],
#         [9.0974e-01, 8.9757e-02, 4.9878e-04],
#         [4.1372e-01, 5.8496e-01, 1.3202e-03],
#         [4.2834e-01, 5.7083e-01, 8.2964e-04],
#         [9.0141e-01, 9.8381e-02, 2.0983e-04],
#         [8.9851e-01, 1.0116e-01, 3.3248e-04],
#         [8.7057e-01, 1.2909e-01, 3.3519e-04],
#         [3.3212e-03, 3.1097e-01, 6.8571e-01],
#         [5.2599e-01, 3.8326e-01, 9.0744e-02],
#         [9.2344e-01, 7.6245e-02, 3.1945e-04],
#         [8.2896e-01, 1.7037e-01, 6.7010e-04],
#         [9.5277e-01, 4.7166e-02, 6.5137e-05],
#         [3.1889e-01, 6.7968e-01, 1.4282e-03],
#         [9.5584e-01, 4.4008e-02, 1.5480e-04],
#         [7.6230e-01, 2.3694e-01, 7.5879e-04],
#         [4.9349e-03, 2.3518e-01, 7.5988e-01],
#         [5.1519e-02, 6.2802e-01, 3.2046e-01],
#         [9.4513e-01, 5.4733e-02, 1.3205e-04],
#         [1.1461e-01, 8.2892e-01, 5.6465e-02],
#         [8.9625e-01, 1.0265e-01, 1.0941e-03],
#         [9.3212e-01, 6.7725e-02, 1.5546e-04],
#         [3.0628e-02, 6.9864e-01, 2.7074e-01],
#         [9.0411e-01, 9.5670e-02, 2.2406e-04],
#         [9.6758e-02, 8.3194e-01, 7.1303e-02],
#         [3.6233e-01, 6.3736e-01, 3.1115e-04],
#         [2.1775e-01, 7.4998e-01, 3.2268e-02],
#         [9.2769e-01, 7.2228e-02, 8.1534e-05],
#         [9.2475e-01, 7.4851e-02, 3.9767e-04],
#         [9.3721e-01, 6.2652e-02, 1.4094e-04],
#         [9.2016e-01, 7.9471e-02, 3.6489e-04],
#         [3.8237e-01, 4.8567e-01, 1.3196e-01],
#         [8.7180e-01, 1.2786e-01, 3.3805e-04],
#         [1.0880e-02, 6.3355e-01, 3.5557e-01],
#         [8.6747e-01, 1.3172e-01, 8.0488e-04],
#         [9.4563e-01, 5.4124e-02, 2.4511e-04]], device='cuda:0',
#        grad_fn=<SoftmaxBackward>)

# %%
import numpy as np

mean = np.array([0.485, 0.456, 0.406]).reshape(-1, 1, 1)
std = np.array([0.229, 0.224, 0.225]).reshape(-1, 1, 1)

# %%
cpu_images = images.cpu().numpy()
cpu_images = (cpu_images * std) + mean
cpu_images = cpu_images.transpose(0, 2, 3, 1)

# %%
outputs[0], labels[0]
# Out:
# (tensor([0.4469, 0.4703, 0.0828], device='cuda:0', grad_fn=<SelectBackward>),
#  tensor(0, device='cuda:0'))

# %%
predict_label = torch.argmax(outputs[0]).item()
real_label = labels[0].item()
predict_label, real_label
# Out:
# (1, 0)

# %%
from prepare import get_classes

args.train_key = "age"
age_classes = get_classes(args)

# %%
age_classes
# Out:
# ['age < 30', '30 <= age < 60', '60 <= age']

# %%
plt.grid(False)
plt.xticks([])
plt.yticks([])
plt.imshow(cpu_images[0])

if predict_label == real_label:
    color = 'blue'
else:
    color = 'red'
    
plt.xlabel("{} {:2.0f}% ({})".format(age_classes[predict_label],
                            100*outputs[0].detach().cpu().numpy()[predict_label],
                            age_classes[real_label]),
                            color=color)

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.grid(False)
plt.xticks([])
plt.yticks([])

thisplot = plt.bar(range(3), outputs[0].detach().cpu().numpy(), color="#777777")
plt.ylim([0, 1])

thisplot[predict_label].set_color('red')
thisplot[real_label].set_color('blue')

# %%
import numpy as np

import torch.nn.functional as F
import matplotlib.pyplot as plt

from prepare import get_classes


def plot_image(ax, image, output, pred_label, true_label, classes):
    ax.grid(False)
    
    color = "red"
    if pred_label == true_label:
        color = "blue"

    ax.imshow(image)
    ax.set_xlabel(
        "{} {:2.0f}% ({})".format(
            classes[pred_label], 100 * output[pred_label], classes[true_label]
        ),
        color=color,
    )


def plot_value_array(ax, output, pred_label, true_label, classes):
    ax.grid(False)
    ax.set_ylim([0, 1])

    thisplot = ax.bar(range(len(classes)), output, color="#777777")

    thisplot[pred_label].set_color("red")
    thisplot[true_label].set_color("blue")

    
def plots_result(args, images, outputs, labels):
    """ all inputs are tensor """

    MEAN = np.array([0.485, 0.456, 0.406]).reshape(-1, 1, 1)
    STD = np.array([0.229, 0.224, 0.225]).reshape(-1, 1, 1)

    outputs = F.softmax(outputs, dim=1)

    # to numpy
    images = images.detach().cpu().numpy()
    outputs = outputs.detach().cpu().numpy()
    labels = labels.detach().cpu().numpy()

    # image preprocessing
    images = np.clip((images * STD) + MEAN, 0, 1)  # 0 ~ 1
    images = images.transpose(0, 2, 3, 1)  # (batch, width, height, channel)

    classes = get_classes(args)

    num_rows = num_cols = int(len(images) ** 0.5)
    num_images = num_rows * num_cols
    
    fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols * 2, figsize=(36, 18))
    plt.setp(axes, xticks=[], yticks=[])
    
    for idx in range(num_images):
        image, output, label = images[idx], outputs[idx], labels[idx]

        num_row = idx // num_rows
        num_col = idx % num_cols

        pred_label = np.argmax(output)
        true_label = label
        
        plot_image(
            axes[num_row][num_col * 2], image, output, pred_label, true_label, classes
        )
        
        plot_value_array(axes[num_row][num_col * 2 + 1], output, pred_label, true_label, classes)

    return fig

# %%
images, labels = next(iter(test_dataloader))
images, labels = images.cuda(), labels.cuda()
outputs = gender_model(images)

# %%
fig1 = plots_result(args, images, outputs, labels)

# %%
fig2 = plots_result(args, images, outputs, labels)

# %% [markdown]
# ## Check Focal Loss

# %%
images, labels = next(iter(train_dataloader))
images, labels = images.cuda(), labels.cuda()
outputs = age_model(images)

# %%
import torchvision
from torchvision.ops.focal_loss import sigmoid_focal_loss

# %%
nn.CrossEntropyLoss()(outputs, labels)
# Out:
# tensor(1.7623, device='cuda:0', grad_fn=<NllLossBackward>)

# %%
sigmoid_focal_loss(outputs, labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-170-94965e37c715> in <module>
# ----> 1 sigmoid_focal_loss(outputs, labels)
#
# /opt/conda/lib/python3.7/site-packages/torchvision/ops/focal_loss.py in sigmoid_focal_loss(inputs, targets, alpha, gamma, reduction)
#      33     p = torch.sigmoid(inputs)
#      34     ce_loss = F.binary_cross_entropy_with_logits(
# ---> 35         inputs, targets, reduction="none"
#      36     )
#      37     p_t = p * targets + (1 - p) * (1 - targets)
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py in binary_cross_entropy_with_logits(input, target, weight, size_average, reduce, reduction, pos_weight)
#    2536     if full:
#    2537         D = input.size(1)
# -> 2538         loss = loss + 0.5 * D * math.log(2 * math.pi)
#    2539
#    2540     # Apply reduction
#
# ValueError: Target size (torch.Size([64])) must be the same as input size (torch.Size([64, 3]))

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
 
class FocalLoss(nn.Module):
    def __init__(self, gamma=0, alpha=None, size_average=True):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha
        if isinstance(alpha,(float,int)): self.alpha = torch.Tensor([alpha,1-alpha])
        if isinstance(alpha,list): self.alpha = torch.Tensor(alpha)
        self.size_average = size_average

    def forward(self, input, target):
        if input.dim()>2:
            input = input.view(input.size(0),input.size(1),-1)  # N,C,H,W => N,C,H*W
            input = input.transpose(1,2)    # N,C,H*W => N,H*W,C
            input = input.contiguous().view(-1,input.size(2))   # N,H*W,C => N*H*W,C
        target = target.view(-1,1)

        logpt = F.log_softmax(input, dim=1)
        logpt = logpt.gather(1,target)
        logpt = logpt.view(-1)
        pt = Variable(logpt.data.exp())

        if self.alpha is not None:
            if self.alpha.type()!=input.data.type():
                self.alpha = self.alpha.type_as(input.data)
            at = self.alpha.gather(0,target.data.view(-1))
            logpt = logpt * Variable(at)

        loss = -1 * (1-pt)**self.gamma * logpt
        if self.size_average: return loss.mean()
        else: return loss.sum()

# %%
f = FocalLoss(gamma=0)

# %%
f(outputs, labels)
# Out:
# tensor(1.7623, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
f(outputs, outputs)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-198-80af87f8d8d2> in <module>
# ----> 1 f(outputs, outputs)
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             will raise an error.
#     721
# --> 722         Returns:
#     723             :class:`torch.utils.hooks.RemovableHandle`:
#     724                 a handle that can be used to remove the added hook by calling
#
# <ipython-input-194-add74adfc3c3> in forward(self, input, target)
#      21
#      22         logpt = F.log_softmax(input, dim=1)
# ---> 23         logpt = logpt.gather(1,target)
#      24         logpt = logpt.view(-1)
#      25         pt = Variable(logpt.data.exp())
#
# RuntimeError: gather_out_cuda(): Expected dtype int64 for index

# %% [markdown]
# ## KLDivLoss 적용 하는 법

# %%
nn.KLDivLoss('mean')(F.softmax(outputs, dim=1).log(), F.softmax(outputs, dim=1))
# Out:
# tensor(0., device='cuda:0', grad_fn=<KlDivBackward>)

# %%
nn.KLDivLoss('mean')(F.log_softmax(outputs, dim=1), F.softmax(outputs, dim=1))
# Out:
# /opt/conda/lib/python3.7/site-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:2352: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   elements in the output, ``'sum'``: the output will be summed. Note: :attr:`size_average`
# tensor(-1.7583e-09, device='cuda:0', grad_fn=<KlDivBackward>)

# %%
nn.KLDivLoss()(torch.tensor([[0.4, 0.6]]), torch.tensor([[0.6, 0.4]]))
# Out:
# tensor(-0.5765)

# %%
nn.KLDivLoss()(torch.tensor([0.6, 0.4]), torch.tensor([0.4, 0.6]))
# Out:
# tensor(-0.5765)

# %%
import torch
a2 = torch.FloatTensor([0.3, 0.6, 0.1])
a1 = torch.FloatTensor([0.4, 0.5, 0.1])
c1 = torch.nn.KLDivLoss()(a1.log(),a2)
print(c1)
# Out:
# tensor(0.0077)
